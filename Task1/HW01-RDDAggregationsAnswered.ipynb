# %% [markdown]
#  # Instructions:
#  - For all cells marked with <font color="red">(CODE Needed)</font> below, replace `#CODE_HERE` with your solution

# %% [markdown]
# # 1. Load Spark Context (No CODE Needed)

# %%
from pyspark import SparkContext, SparkConf
myconf = SparkConf() \
        .setMaster("local[*]") 
        #.set("spark.driver.cores",4) \
        #.set("spark.executor.memory","2g") 
sc = SparkContext(conf=myconf)

# %% [markdown]
# # 2. Load some printing functions (No CODE Needed)

# %%
#These are some printing helper functions we will use to make the output more clear
from pprint import pprint
def title(s):
    pprint("---- %s -----" %s)    
    
def see(s, v):
    pprint("---- %s -----" %s)
    pprint(v)

# %% [markdown]
# # 3. Load each file in an RDD and add the year to the data (No CODE Needed)

# %%
def createOneYearRdd(year):
    file = "../data/flight-data/csv/%s"%year+"*"
    see("year:"+str(year), file)
    fileRDD =sc.textFile(file)
    linesRDD = fileRDD.filter(lambda x:  not x.startswith("DEST_")) \
              .filter(lambda line: line.count(',')==2)
    arrRDD = linesRDD.map(lambda line: (line.split(","), year))
    see("rdd count for year:"+str(year), arrRDD.count())
    title("rdd elements for year:"+str(year))
    for arr in (arrRDD.take(5)):
        print(arr)
    return arrRDD

separateRDDs  = list(map(createOneYearRdd, range(2010,2016)))
                 
see("arryay of RDDs", separateRDDs)
# Out:
# '---- year:2010 -----'
# '../data/flight-data/csv/2010*'
# '---- rdd count for year:2010 -----'
# 253
# '---- rdd elements for year:2010 -----'
# (['United States', 'Romania', '1'], 2010)
# (['United States', 'Ireland', '264'], 2010)
# (['United States', 'India', '69'], 2010)
# (['Egypt', 'United States', '24'], 2010)
# (['Equatorial Guinea', 'United States', '1'], 2010)
# '---- year:2011 -----'
# '../data/flight-data/csv/2011*'
# '---- rdd count for year:2011 -----'
# 253
# '---- rdd elements for year:2011 -----'
# (['United States', 'Saint Martin', '2'], 2011)
# (['United States', 'Guinea', '2'], 2011)
# (['United States', 'Croatia', '1'], 2011)
# (['United States', 'Romania', '3'], 2011)
# (['United States', 'Ireland', '268'], 2011)
# '---- year:2012 -----'
# '../data/flight-data/csv/2012*'
# '---- rdd count for year:2012 -----'
# 243
# '---- rdd elements for year:2012 -----'
# (['United States', 'Croatia', '1'], 2012)
# (['United States', 'Ireland', '252'], 2012)
# (['Egypt', 'United States', '13'], 2012)
# (['United States', 'India', '62'], 2012)
# (['United States', 'Singapore', '25'], 2012)
# '---- year:2013 -----'
# '../data/flight-data/csv/2013*'
# '---- rdd count for year:2013 -----'
# 246
# '---- rdd elements for year:2013 -----'
# (['United States', 'Romania', '12'], 2013)
# (['United States', 'Croatia', '1'], 2013)
# (['United States', 'Ireland', '266'], 2013)
# (['Egypt', 'United States', '13'], 2013)
# (['United States', 'India', '60'], 2013)
# '---- year:2014 -----'
# '../data/flight-data/csv/2014*'
# '---- rdd count for year:2014 -----'
# 239
# '---- rdd elements for year:2014 -----'
# (['United States', 'Saint Martin', '1'], 2014)
# (['United States', 'Romania', '12'], 2014)
# (['United States', 'Croatia', '2'], 2014)
# (['United States', 'Ireland', '291'], 2014)
# (['United States', 'India', '62'], 2014)
# '---- year:2015 -----'
# '../data/flight-data/csv/2015*'
# '---- rdd count for year:2015 -----'
# 254
# '---- rdd elements for year:2015 -----'
# (['United States', 'Romania', '15'], 2015)
# (['United States', 'Croatia', '1'], 2015)
# (['United States', 'Ireland', '344'], 2015)
# (['Egypt', 'United States', '15'], 2015)
# (['United States', 'India', '62'], 2015)
# '---- arryay of RDDs -----'
# [PythonRDD[114] at RDD at PythonRDD.scala:48,
#  PythonRDD[115] at RDD at PythonRDD.scala:48,
#  PythonRDD[116] at RDD at PythonRDD.scala:48,
#  PythonRDD[117] at RDD at PythonRDD.scala:48,
#  PythonRDD[118] at RDD at PythonRDD.scala:48,
#  PythonRDD[119] at RDD at PythonRDD.scala:48]

# %% [markdown]
# # 4. Merge all RDDs into one Rdd  (No CODE Needed)

# %%
allYearsRdd  =sc.union(separateRDDs)
see("allYearsRDD count", allYearsRdd.count())
see("allYearsRDD sample", allYearsRdd.takeSample(False, 10, 17))
# Out:
# '---- allYearsRDD count -----'
# 1488
# '---- allYearsRDD sample -----'
# [(['United States', 'Saint Barthelemy', '39'], 2011),
#  (['Egypt', 'United States', '13'], 2011),
#  (['Egypt', 'United States', '13'], 2013),
#  (['United States', 'Poland', '33'], 2015),
#  (['Haiti', 'United States', '201'], 2014),
#  (['United States', 'Canada', '8177'], 2014),
#  (['United States', 'Netherlands', '607'], 2012),
#  (['United States', 'Saint Lucia', '121'], 2010),
#  (['Italy', 'United States', '381'], 2012),
#  (['Greece', 'United States', '17'], 2012)]

# %% [markdown]
# # 5. Compute an RDD containing all flights which departed from  the US  <font color="red">(CODE Needed)</font>
# - Hint: make 1 `filter` transformation

# %%
fromUSRdd = allYearsRdd.filter(lambda v: v[0][1]=='United States')

see("fromUSRdd count",fromUSRdd.count())

see("fromUSRdd take(10)",fromUSRdd.take(10))
# Out:
# '---- fromUSRdd count -----'
# 765
# '---- fromUSRdd take(10) -----'
# [(['Egypt', 'United States', '24'], 2010),
#  (['Equatorial Guinea', 'United States', '1'], 2010),
#  (['Costa Rica', 'United States', '477'], 2010),
#  (['Senegal', 'United States', '29'], 2010),
#  (['Guyana', 'United States', '17'], 2010),
#  (['Malta', 'United States', '1'], 2010),
#  (['Bolivia', 'United States', '46'], 2010),
#  (['Anguilla', 'United States', '21'], 2010),
#  (['Turks and Caicos Islands', 'United States', '136'], 2010),
#  (['Saint Vincent and the Grenadines', 'United States', '1'], 2010)]

# %% [markdown]
# ### Expectated output for step 5.
#
# <pre>
# '---- fromUSRdd count -----'
# 765
# '---- fromUSRdd take(10) -----'
# [(['Egypt', 'United States', '24'], 2010),
#  (['Equatorial Guinea', 'United States', '1'], 2010),
#  (['Costa Rica', 'United States', '477'], 2010),
#  (['Senegal', 'United States', '29'], 2010),
#  (['Guyana', 'United States', '17'], 2010),
#  (['Malta', 'United States', '1'], 2010),
#  (['Bolivia', 'United States', '46'], 2010),
#  (['Anguilla', 'United States', '21'], 2010),
#  (['Turks and Caicos Islands', 'United States', '136'], 2010),
#  (['Saint Vincent and the Grenadines', 'United States', '1'], 2010)]
# </pre>

# %% [markdown]
# # 6. Create an RDD with a composite key (destination, year) and a value n which is the corresponding number of flights  as an integer <font color="red">(CODE Needed)</font>
# - Use the `int()` function to convert a string to an integer
# - Hint: make 1 `map` transformation

# %%
compositeKeyRdd =  fromUSRdd.map(lambda v: ((v[0][0],v[1]),int(v[0][2])))

see("compositeKeyRdd count",compositeKeyRdd.count())

see("compositeKeyRdd take(10)",compositeKeyRdd.take(10))
# Out:
# '---- compositeKeyRdd count -----'
# 765
# '---- compositeKeyRdd take(10) -----'
# [(('Egypt', 2010), 24),
#  (('Equatorial Guinea', 2010), 1),
#  (('Costa Rica', 2010), 477),
#  (('Senegal', 2010), 29),
#  (('Guyana', 2010), 17),
#  (('Malta', 2010), 1),
#  (('Bolivia', 2010), 46),
#  (('Anguilla', 2010), 21),
#  (('Turks and Caicos Islands', 2010), 136),
#  (('Saint Vincent and the Grenadines', 2010), 1)]

# %% [markdown]
# ### Exepected output for step 6
# <pre>
# '---- compositeKeyRdd count -----'
# 765
# '---- compositeKeyRdd take(10) -----'
# [(('Egypt', 2010), 24),
#  (('Equatorial Guinea', 2010), 1),
#  (('Costa Rica', 2010), 477),
#  (('Senegal', 2010), 29),
#  (('Guyana', 2010), 17),
#  (('Malta', 2010), 1),
#  (('Bolivia', 2010), 46),
#  (('Anguilla', 2010), 21),
#  (('Turks and Caicos Islands', 2010), 136),
#  (('Saint Vincent and the Grenadines', 2010), 1)]
#  </pre>

# %% [markdown]
# # 7. Sum all the flights for the same destination and the same year <font color="red">(CODE Needed)</font>
# - Hint: make 1 `reduceByKey` transformation

# %%
groupedRdd = compositeKeyRdd.reduceByKey(lambda v1,v2: v1+v2)

see("groupedRdd count",groupedRdd.count())

see("groupedRdd take(10)",groupedRdd.take(10))
# Out:
# '---- groupedRdd count -----'
# 765
# '---- groupedRdd take(10) -----'
# [(('Ethiopia', 2010), 12),
#  (('Fiji', 2010), 53),
#  (('Federated States of Micronesia', 2010), 46),
#  (('French Guiana', 2010), 4),
#  (('Netherlands', 2010), 586),
#  (('Denmark', 2010), 98),
#  (('Belgium', 2010), 408),
#  (('Guatemala', 2010), 386),
#  (('Vietnam', 2010), 1),
#  (('South Korea', 2010), 683)]

# %% [markdown]
# ### Exepected output for step  7
# <pre>
# '---- groupedRdd count -----'
# 765
# '---- groupedRdd take(10) -----'
# [(('Ethiopia', 2010), 12),
#  (('Fiji', 2010), 53),
#  (('Federated States of Micronesia', 2010), 46),
#  (('French Guiana', 2010), 4),
#  (('Netherlands', 2010), 586),
#  (('Denmark', 2010), 98),
#  (('Belgium', 2010), 408),
#  (('Guatemala', 2010), 386),
#  (('Vietnam', 2010), 1),
#  (('South Korea', 2010), 683)]
#  </pre>

# %% [markdown]
# # 8. Sort the summed data by the highest sum <font color="red">(CODE Needed)</font>
# - Hint: make 1 `map` transformation, 1 `sortByKey(ascending=False)`, then 1 `map`

# %%
sortedByCountRdd = groupedRdd.map(lambda v: (v[1],v[0])).sortByKey(ascending=False).map(lambda v: (v[1],v[0]))

see("sortedByCountRdd count",sortedByCountRdd.count())

see("sortedByCountRdd take(10)",sortedByCountRdd.take(10))
# Out:
# '---- sortedByCountRdd count -----'
# 765
# '---- sortedByCountRdd take(10) -----'
# [(('United States', 2015), 370002),
#  (('United States', 2014), 358354),
#  (('United States', 2011), 352742),
#  (('United States', 2010), 348113),
#  (('United States', 2012), 347452),
#  (('United States', 2013), 343132),
#  (('Canada', 2011), 8514),
#  (('Canada', 2015), 8399),
#  (('Canada', 2010), 8271),
#  (('Canada', 2012), 8034)]

# %% [markdown]
# ### Exepected output for step  8
# <pre>
# '---- sortedByCountRdd count -----'
# 765
# '---- sortedByCountRdd take(10) -----'
# [(('United States', 2015), 370002),
#  (('United States', 2014), 358354),
#  (('United States', 2011), 352742),
#  (('United States', 2010), 348113),
#  (('United States', 2012), 347452),
#  (('United States', 2013), 343132),
#  (('Canada', 2011), 8514),
#  (('Canada', 2015), 8399),
#  (('Canada', 2010), 8271),
#  (('Canada', 2012), 8034)]
#  </pre>

# %% [markdown]
# # 9. Compute the Sum of all Trips <font color="red">(CODE Needed)</font>
# - Hint: make 1 `map` , 1 `sum`

# %%
sumAllTrips = sortedByCountRdd.map(lambda v: (v[1])).sum()
see("sumAllTrips", sumAllTrips)
# Out:
# '---- sumAllTrips -----'
# 2352144

# %% [markdown]
# ### Exepected output for step  9
# <pre>
# '---- sumAllTrips -----'
# 2352144
#  </pre>

# %% [markdown]
# # 10. Compute the Sum of Each Year's Trip <font color="red">(CODE Needed)</font>
# - Hint: make 1 `map` , 1 `reduceByKey`, 1 `collectAsMap`

# %%
TPY = sortedByCountRdd.map(lambda v: (v[0][1],v[1])).reduceByKey(lambda v1,v2: v1+v2).collectAsMap()

see("TPY", TPY)
# Out:
# '---- TPY -----'
# {2010: 385434,
#  2011: 390613,
#  2012: 385244,
#  2013: 380985,
#  2014: 397960,
#  2015: 411908}

# %% [markdown]
# ### Exepected output for step  10
# <pre>
# '---- TPY -----'
# {2010: 385434,
#  2011: 390613,
#  2012: 385244,
#  2013: 380985,
#  2014: 397960,
#  2015: 411908}
#  </pre>

# %% [markdown]
# # 11. Use the above sums to compute percent Per Year, percent from Total for each country, year pair <font color="red">(CODE Needed)</font>
# - Hint: make 1 `map`
# - use the function `percent`
# - use TPY as a lookup table

# %%
def percent(number, total):
    return 100.0* number/float(total)

stats = sortedByCountRdd.map(lambda v: (v[0],v[1], percent(v[1],TPY[v[0][1]]), percent(v[1],sum(TPY.values()))))

see("stats count",stats.count())

see("stats take(10)",stats.take(10))
# Out:
# '---- stats count -----'
# 765
# '---- stats take(10) -----'
# [(('United States', 2015), 370002, 89.8263689950183, 15.730414464420546),
#  (('United States', 2014), 358354, 90.04774349180822, 15.235206688025903),
#  (('United States', 2011), 352742, 90.30472616118767, 14.99661585345115),
#  (('United States', 2010), 348113, 90.31714898011073, 14.799816677890469),
#  (('United States', 2012), 347452, 90.19011327885704, 14.771714656925766),
#  (('United States', 2013), 343132, 90.06443823247635, 14.588052432164018),
#  (('Canada', 2011), 8514, 2.1796509588774566, 0.36196763463461423),
#  (('Canada', 2015), 8399, 2.039047554308244, 0.3570784781884102),
#  (('Canada', 2010), 8271, 2.145892682015598, 0.3516366344917658),
#  (('Canada', 2012), 8034, 2.0854315706409445, 0.3415607207721976)]

# %% [markdown]
# ### Exepected output for step  11
# <pre>
# '---- stats count -----'
# 765
# '---- stats take(10) -----'
# [(('United States', 2015), 370002, 89.8263689950183, 15.730414464420546),
#  (('United States', 2014), 358354, 90.04774349180822, 15.235206688025903),
#  (('United States', 2011), 352742, 90.30472616118767, 14.99661585345115),
#  (('United States', 2010), 348113, 90.31714898011073, 14.799816677890469),
#  (('United States', 2012), 347452, 90.19011327885704, 14.771714656925766),
#  (('United States', 2013), 343132, 90.06443823247635, 14.588052432164018),
#  (('Canada', 2011), 8514, 2.1796509588774566, 0.36196763463461423),
#  (('Canada', 2015), 8399, 2.039047554308244, 0.3570784781884102),
#  (('Canada', 2010), 8271, 2.145892682015598, 0.3516366344917658),
#  (('Canada', 2012), 8034, 2.0854315706409445, 0.3415607207721976)]
#  </pre>

# %% [markdown]
# # 12. Transform the above table into the format below <font color="red">(CODE Needed)</font>
# - Hint: make 1 `map`, 1 `groupByKey`, 1 `mapValues`
# - you will also need the python functions `list`, `sorted`, `dict`
# - use TPY as a lookup table

# %%
preTable = stats.map(lambda v: (v[0][0],(v[0][1],(v[1],v[2],v[3])))).groupByKey().sortByKey()\
.mapValues(lambda v: dict(list(v)))


see("preTable count",preTable.count())

see("preTable take(5)",preTable.take(5))
# Out:
# '---- preTable count -----'
# 165
# '---- preTable take(5) -----'
# [('Afghanistan',
#   {2010: (11, 0.002853925704530477, 0.0004676584426803801),
#    2011: (8, 0.0020480629164927946, 0.0003401152310402764),
#    2012: (5, 0.0012978787469759426, 0.00021257201940017278)}),
#  ('Algeria',
#   {2013: (2, 0.0005249550507237817, 8.50288077600691e-05),
#    2014: (9, 0.002261533822494723, 0.000382629634920311),
#    2015: (4, 0.0009710906318886742, 0.0001700576155201382)}),
#  ('Angola',
#   {2010: (14, 0.0036322690784933347, 0.0005952016543204838),
#    2011: (13, 0.0033281022393007913, 0.0005526872504404493),
#    2012: (12, 0.003114908992742262, 0.0005101728465604147),
#    2013: (12, 0.0031497303043426907, 0.0005101728465604147),
#    2014: (13, 0.003266659965825711, 0.0005526872504404493),
#    2015: (15, 0.003641589869582528, 0.0006377160582005184)}),
#  ('Anguilla',
#   {2010: (21, 0.0054484036177400025, 0.0008928024814807257),
#    2011: (21, 0.005376165155793586, 0.0008928024814807257),
#    2012: (19, 0.004931939238508582, 0.0008077736737206565),
#    2013: (22, 0.0057745055579616, 0.0009353168853607602),
#    2014: (34, 0.008543572218313398, 0.0014454897319211748),
#    2015: (41, 0.00995367897685891, 0.0017430905590814169)}),
#  ('Antigua and Barbuda',
#   {2010: (123, 0.03191207833247715, 0.00522927167724425),
#    2011: (146, 0.0373771482259935, 0.006207102966485045),
#    2012: (145, 0.03763848366230233, 0.006164588562605011),
#    2013: (123, 0.03228473561951258, 0.00522927167724425),
#    2014: (115, 0.028897376620765906, 0.0048891564462039735),
#    2015: (126, 0.030589354904493236, 0.005356814888884354)})]

# %% [markdown]
# ### Exepected output for step  12
# <pre>
# '---- preTable count -----'
# 165
# '---- preTable take(10) -----'
# [('Afghanistan',
#   {2010: (11, 0.002853925704530477, 0.0004676584426803801),
#    2011: (8, 0.0020480629164927946, 0.0003401152310402764),
#    2012: (5, 0.0012978787469759426, 0.00021257201940017278)}),
#  ('Algeria',
#   {2013: (2, 0.0005249550507237817, 8.50288077600691e-05),
#    2014: (9, 0.002261533822494723, 0.000382629634920311),
#    2015: (4, 0.0009710906318886742, 0.0001700576155201382)}),
#  ('Angola',
#   {2010: (14, 0.0036322690784933347, 0.0005952016543204838),
#    2011: (13, 0.0033281022393007913, 0.0005526872504404493),
#    2012: (12, 0.003114908992742262, 0.0005101728465604147),
#    2013: (12, 0.0031497303043426907, 0.0005101728465604147),
#    2014: (13, 0.003266659965825711, 0.0005526872504404493),
#    2015: (15, 0.003641589869582528, 0.0006377160582005184)}),
#  ('Anguilla',
#   {2010: (21, 0.0054484036177400025, 0.0008928024814807257),
#    2011: (21, 0.005376165155793586, 0.0008928024814807257),
#    2012: (19, 0.004931939238508582, 0.0008077736737206565),
#    2013: (22, 0.0057745055579616, 0.0009353168853607602),
#    2014: (34, 0.008543572218313398, 0.0014454897319211748),
#    2015: (41, 0.00995367897685891, 0.0017430905590814169)}),
#  ('Antigua and Barbuda',
#   {2010: (123, 0.03191207833247715, 0.00522927167724425),
#    2011: (146, 0.0373771482259935, 0.006207102966485045),
#    2012: (145, 0.03763848366230233, 0.006164588562605011),
#    2013: (123, 0.03228473561951258, 0.00522927167724425),
#    2014: (115, 0.028897376620765906, 0.0048891564462039735),
#    2015: (126, 0.030589354904493236, 0.005356814888884354)})]
#  </pre>

# %% [markdown]
# # 13. Transform the above table into the format below<font color="red">(CODE Needed)</font>
# - Hint: make 1 `map`, you will need more than one line in the map, so create a mapping function

# %%
def loopDic(cntry,dct):
#    tempL = keysList
#    tempJ = keysList
#    tempK = keysList
#    i = 0
#    while i < len(keysList):
#        tempL[i]=('PcntTotal-' + str(keysList[i]) , pcntList[i][2])
#        tempJ[i]=('PcntYear-' + str(keysList[i]) , pcntList[i][1])
#        tempK[i]=('Tot-' + str(keysList[i]) , pcntList[i][0])
#        i+=1

    out = {"Country":cntry}
    for y,vs in dct.items():
        out['PcntTotal-' + str(y)] = vs[2]
        out['PcntYear-' + str(y)] = vs[1]
        out['Tot-' + str(y)] = vs[0]        
#    tempL = tempL.extend(tempJ)
#    tempL = tempL.extend(tempK)
#     cntry = ('Country',cntry)    
#     tempL.insert(0,cntry)

    return out

Table = preTable.map(lambda v:  loopDic(v[0], v[1]))

see("Table count",Table.count())

see("Table take(3)",Table.take(3))
# Out:
# '---- Table count -----'
# 165
# '---- Table take(3) -----'
# [{'Country': 'Afghanistan',
#   'PcntTotal-2010': 0.0004676584426803801,
#   'PcntTotal-2011': 0.0003401152310402764,
#   'PcntTotal-2012': 0.00021257201940017278,
#   'PcntYear-2010': 0.002853925704530477,
#   'PcntYear-2011': 0.0020480629164927946,
#   'PcntYear-2012': 0.0012978787469759426,
#   'Tot-2010': 11,
#   'Tot-2011': 8,
#   'Tot-2012': 5},
#  {'Country': 'Algeria',
#   'PcntTotal-2013': 8.50288077600691e-05,
#   'PcntTotal-2014': 0.000382629634920311,
#   'PcntTotal-2015': 0.0001700576155201382,
#   'PcntYear-2013': 0.0005249550507237817,
#   'PcntYear-2014': 0.002261533822494723,
#   'PcntYear-2015': 0.0009710906318886742,
#   'Tot-2013': 2,
#   'Tot-2014': 9,
#   'Tot-2015': 4},
#  {'Country': 'Angola',
#   'PcntTotal-2010': 0.0005952016543204838,
#   'PcntTotal-2011': 0.0005526872504404493,
#   'PcntTotal-2012': 0.0005101728465604147,
#   'PcntTotal-2013': 0.0005101728465604147,
#   'PcntTotal-2014': 0.0005526872504404493,
#   'PcntTotal-2015': 0.0006377160582005184,
#   'PcntYear-2010': 0.0036322690784933347,
#   'PcntYear-2011': 0.0033281022393007913,
#   'PcntYear-2012': 0.003114908992742262,
#   'PcntYear-2013': 0.0031497303043426907,
#   'PcntYear-2014': 0.003266659965825711,
#   'PcntYear-2015': 0.003641589869582528,
#   'Tot-2010': 14,
#   'Tot-2011': 13,
#   'Tot-2012': 12,
#   'Tot-2013': 12,
#   'Tot-2014': 13,
#   'Tot-2015': 15}]

# %% [markdown]
# ### Exepected output for step  13
# <pre>
# '---- Table count -----'
# 165
# '---- Table take(3) -----'
# [{'Country': 'Afghanistan',
#   'PcntTotal-2010': 0.0004676584426803801,
#   'PcntTotal-2011': 0.0003401152310402764,
#   'PcntTotal-2012': 0.00021257201940017278,
#   'PcntYear-2010': 0.002853925704530477,
#   'PcntYear-2011': 0.0020480629164927946,
#   'PcntYear-2012': 0.0012978787469759426,
#   'Tot-2010': 11,
#   'Tot-2011': 8,
#   'Tot-2012': 5},
#  {'Country': 'Algeria',
#   'PcntTotal-2013': 8.50288077600691e-05,
#   'PcntTotal-2014': 0.000382629634920311,
#   'PcntTotal-2015': 0.0001700576155201382,
#   'PcntYear-2013': 0.0005249550507237817,
#   'PcntYear-2014': 0.002261533822494723,
#   'PcntYear-2015': 0.0009710906318886742,
#   'Tot-2013': 2,
#   'Tot-2014': 9,
#   'Tot-2015': 4},
#  {'Country': 'Angola',
#   'PcntTotal-2010': 0.0005952016543204838,
#   'PcntTotal-2011': 0.0005526872504404493,
#   'PcntTotal-2012': 0.0005101728465604147,
#   'PcntTotal-2013': 0.0005101728465604147,
#   'PcntTotal-2014': 0.0005526872504404493,
#   'PcntTotal-2015': 0.0006377160582005184,
#   'PcntYear-2010': 0.0036322690784933347,
#   'PcntYear-2011': 0.0033281022393007913,
#   'PcntYear-2012': 0.003114908992742262,
#   'PcntYear-2013': 0.0031497303043426907,
#   'PcntYear-2014': 0.003266659965825711,
#   'PcntYear-2015': 0.003641589869582528,
#   'Tot-2010': 14,
#   'Tot-2011': 13,
#   'Tot-2012': 12,
#   'Tot-2013': 12,
#   'Tot-2014': 13,
#   'Tot-2015': 15}]
#  </pre>

# %% [markdown]
# # 14. Optional: Convert the data to a Pandas Dataframe <font color="green">(No CODE Needed)</font>

# %%
import pandas as pd

pd.DataFrame(data=Table.collect())
# Out:
#                       Country  PcntTotal-2010  PcntTotal-2011  PcntTotal-2012  \
# 0                 Afghanistan        0.000468        0.000340        0.000213
# 1                     Algeria             NaN             NaN             NaN
# 2                      Angola        0.000595        0.000553        0.000510
# 3                    Anguilla        0.000893        0.000893        0.000808
# 4         Antigua and Barbuda        0.005229        0.006207        0.006165
# 5                   Argentina        0.007823        0.007780        0.008843
# 6                       Aruba        0.015263        0.014752        0.014838
# 7                   Australia        0.012329        0.011904        0.011776
# 8                     Austria        0.001531        0.001445        0.001445
# 9                  Azerbaijan        0.000043             NaN             NaN
# 10                    Bahrain        0.001275        0.001701        0.002763
# 11                   Barbados        0.005527        0.005484        0.005144
# 12                    Belarus             NaN        0.000043        0.000043
# 13                    Belgium        0.017346        0.015985        0.014965
# 14                     Belize        0.005144        0.004804        0.004804
# 15                    Bermuda        0.007780        0.008120        0.008078
# 16                    Bolivia        0.001956        0.002593        0.001488
# 17                     Brazil        0.042302        0.041196        0.041622
# 18     British Virgin Islands        0.002083        0.003104        0.003529
# 19                     Brunei             NaN             NaN             NaN
# 20                   Bulgaria        0.000043        0.000170        0.000255
# 21               Burkina Faso             NaN             NaN             NaN
# 22                    Burundi             NaN             NaN             NaN
# 23                   Cameroon             NaN             NaN        0.000043
# 24                     Canada        0.351637        0.361968        0.341561
# 25                 Cape Verde        0.000765        0.000553        0.000808
# 26             Cayman Islands        0.010501        0.010671        0.010969
# 27                       Chad             NaN             NaN             NaN
# 28                      Chile        0.007057        0.007568        0.007568
# 29                      China        0.019046        0.021427        0.021640
# ..                        ...             ...             ...             ...
# 135              Sint Maarten        0.002593        0.010203        0.010331
# 136                  Slovakia        0.000043             NaN             NaN
# 137           Solomon Islands             NaN             NaN        0.000085
# 138              South Africa        0.001063        0.001020        0.001020
# 139               South Korea        0.029037        0.030313        0.034819
# 140                     Spain        0.017941        0.018919        0.016581
# 141                  Suriname        0.000510        0.000468        0.000595
# 142                    Sweden        0.002763        0.002508        0.002126
# 143               Switzerland        0.013392        0.013350        0.012117
# 144                    Taiwan        0.011691        0.010544        0.009736
# 145                  Tanzania             NaN             NaN             NaN
# 146                  Thailand        0.000680        0.000510        0.000255
# 147               The Bahamas        0.038391        0.034479        0.041452
# 148                The Gambia             NaN        0.000043        0.000085
# 149                      Togo             NaN        0.000043             NaN
# 150       Trinidad and Tobago        0.007950        0.008715        0.009183
# 151                   Tunisia             NaN             NaN        0.000085
# 152                    Turkey        0.003189        0.004421        0.003996
# 153  Turks and Caicos Islands        0.005782        0.006930        0.007780
# 154                    Uganda        0.000085             NaN             NaN
# 155                   Ukraine        0.000808        0.000638        0.000595
# 156      United Arab Emirates        0.007015        0.006675        0.007993
# 157            United Kingdom        0.069256        0.073380        0.078737
# 158             United States       14.799817       14.996616       14.771715
# 159                   Uruguay        0.002296        0.002126        0.002253
# 160                 Venezuela        0.016028        0.015858        0.016538
# 161                   Vietnam        0.000043        0.000043        0.000085
# 162                     Yemen             NaN        0.000043             NaN
# 163                    Zambia             NaN             NaN             NaN
# 164                  Zimbabwe             NaN             NaN             NaN
#
#      PcntTotal-2013  PcntTotal-2014  PcntTotal-2015  PcntYear-2010  \
# 0               NaN             NaN             NaN       0.002854
# 1          0.000085        0.000383        0.000170            NaN
# 2          0.000510        0.000553        0.000638       0.003632
# 3          0.000935        0.001445        0.001743       0.005448
# 4          0.005229        0.004889        0.005357       0.031912
# 5          0.007483        0.008290        0.007653       0.047738
# 6          0.014965        0.014923        0.014710       0.093142
# 7          0.012542        0.012457        0.013987       0.075240
# 8          0.001488        0.001998        0.002636       0.009340
# 9          0.000128        0.000298        0.000893       0.000259
# 10         0.002126        0.001743        0.000808       0.007783
# 11         0.004124        0.004336        0.006547       0.033728
# 12              NaN             NaN             NaN            NaN
# 13         0.011266        0.011011        0.011011       0.105855
# 14         0.005824        0.006037        0.007993       0.031393
# 15         0.006930        0.007865        0.007780       0.047479
# 16         0.001403        0.001403        0.001275       0.011935
# 17         0.038773        0.039411        0.036265       0.258151
# 18         0.004294        0.004592        0.004549       0.012713
# 19         0.000043             NaN             NaN            NaN
# 20              NaN             NaN        0.000128       0.000259
# 21              NaN        0.000085        0.000043            NaN
# 22         0.000043             NaN             NaN            NaN
# 23              NaN             NaN             NaN            NaN
# 24         0.334163        0.339010        0.357078       2.145893
# 25         0.000893        0.001020        0.000850       0.004670
# 26         0.011649        0.012032        0.013350       0.064084
# 27              NaN        0.000043             NaN            NaN
# 28         0.006250        0.006632        0.007398       0.043068
# 29         0.023085        0.027762        0.032821       0.116233
# ..              ...             ...             ...            ...
# 135        0.011521        0.012329        0.013817       0.015826
# 136             NaN        0.000043             NaN       0.000259
# 137             NaN             NaN             NaN            NaN
# 138        0.001020        0.001360        0.001531       0.006486
# 139        0.035797        0.041154        0.044555       0.177203
# 140        0.015730        0.016496        0.017856       0.109487
# 141        0.000638        0.000425        0.000043       0.003113
# 142        0.002976        0.003996        0.005017       0.016864
# 143        0.012244        0.012839        0.012499       0.081726
# 144        0.010331        0.011266        0.011309       0.071348
# 145        0.000085             NaN             NaN            NaN
# 146        0.000085             NaN        0.000128       0.004151
# 147        0.036775        0.040389        0.040601       0.234281
# 148             NaN             NaN             NaN            NaN
# 149             NaN             NaN             NaN            NaN
# 150        0.007780        0.007993        0.008971       0.048517
# 151             NaN        0.000085        0.000128            NaN
# 152        0.004209        0.003869        0.005867       0.019459
# 153        0.007695        0.008205        0.009778       0.035285
# 154             NaN             NaN             NaN       0.000519
# 155        0.000170        0.000468        0.000595       0.004930
# 156        0.008588        0.010501        0.013605       0.042809
# 157        0.076611        0.081288        0.086092       0.422640
# 158       14.588052       15.235207       15.730414      90.317149
# 159        0.002423        0.002551        0.001828       0.014010
# 160        0.014880        0.014242        0.012329       0.097812
# 161             NaN             NaN             NaN       0.000259
# 162             NaN             NaN             NaN            NaN
# 163             NaN             NaN        0.000043            NaN
# 164        0.000085             NaN             NaN            NaN
#
#      PcntYear-2011  PcntYear-2012  PcntYear-2013  PcntYear-2014  \
# 0         0.002048       0.001298            NaN            NaN
# 1              NaN            NaN       0.000525       0.002262
# 2         0.003328       0.003115       0.003150       0.003267
# 3         0.005376       0.004932       0.005775       0.008544
# 4         0.037377       0.037638       0.032285       0.028897
# 5         0.046849       0.053992       0.046196       0.049000
# 6         0.088835       0.090592       0.092392       0.088200
# 7         0.071682       0.071902       0.077431       0.073625
# 8         0.008704       0.008826       0.009187       0.011810
# 9              NaN            NaN       0.000787       0.001759
# 10        0.010240       0.016872       0.013124       0.010303
# 11        0.033025       0.031409       0.025460       0.025631
# 12        0.000256       0.000260            NaN            NaN
# 13        0.096259       0.091371       0.069557       0.065082
# 14        0.028929       0.029332       0.035959       0.035682
# 15        0.048898       0.049319       0.042784       0.046487
# 16        0.015616       0.009085       0.008662       0.008292
# 17        0.248072       0.254125       0.239380       0.232938
# 18        0.018689       0.021545       0.026510       0.027138
# 19             NaN            NaN       0.000262            NaN
# 20        0.001024       0.001557            NaN            NaN
# 21             NaN            NaN            NaN       0.000503
# 22             NaN            NaN       0.000262            NaN
# 23             NaN       0.000260            NaN            NaN
# 24        2.179651       2.085432       2.063073       2.003719
# 25        0.003328       0.004932       0.005512       0.006031
# 26        0.064258       0.066971       0.071919       0.071113
# 27             NaN            NaN            NaN       0.000251
# 28        0.045569       0.046204       0.038584       0.039200
# 29        0.129028       0.132124       0.142525       0.164087
# ..             ...            ...            ...            ...
# 135       0.061442       0.063077       0.071131       0.072872
# 136            NaN            NaN            NaN       0.000251
# 137            NaN       0.000519            NaN            NaN
# 138       0.006144       0.006230       0.006299       0.008041
# 139       0.182534       0.212593       0.221006       0.243241
# 140       0.113923       0.101235       0.097117       0.097497
# 141       0.002816       0.003634       0.003937       0.002513
# 142       0.015104       0.012979       0.018373       0.023620
# 143       0.080386       0.073979       0.075594       0.075887
# 144       0.063490       0.059443       0.063782       0.066590
# 145            NaN            NaN       0.000525            NaN
# 146       0.003072       0.001557       0.000525            NaN
# 147       0.207622       0.253086       0.227043       0.238717
# 148       0.000256       0.000519            NaN            NaN
# 149       0.000256            NaN            NaN            NaN
# 150       0.052482       0.056068       0.048033       0.047241
# 151            NaN       0.000519            NaN       0.000503
# 152       0.026625       0.024400       0.025985       0.022867
# 153       0.041729       0.047502       0.047508       0.048497
# 154            NaN            NaN            NaN            NaN
# 155       0.003840       0.003634       0.001050       0.002764
# 156       0.040193       0.048800       0.053020       0.062067
# 157       0.441870       0.480734       0.472985       0.480450
# 158      90.304726      90.190113      90.064438      90.047743
# 159       0.012800       0.013758       0.014961       0.015077
# 160       0.095491       0.100975       0.091867       0.084179
# 161       0.000256       0.000519            NaN            NaN
# 162       0.000256            NaN            NaN            NaN
# 163            NaN            NaN            NaN            NaN
# 164            NaN            NaN       0.000525            NaN
#
#      PcntYear-2015  Tot-2010  Tot-2011  Tot-2012  Tot-2013  Tot-2014  Tot-2015
# 0              NaN      11.0       8.0       5.0       NaN       NaN       NaN
# 1         0.000971       NaN       NaN       NaN       2.0       9.0       4.0
# 2         0.003642      14.0      13.0      12.0      12.0      13.0      15.0
# 3         0.009954      21.0      21.0      19.0      22.0      34.0      41.0
# 4         0.030589     123.0     146.0     145.0     123.0     115.0     126.0
# 5         0.043699     184.0     183.0     208.0     176.0     195.0     180.0
# 6         0.083999     359.0     347.0     349.0     352.0     351.0     346.0
# 7         0.079872     290.0     280.0     277.0     295.0     293.0     329.0
# 8         0.015052      36.0      34.0      34.0      35.0      47.0      62.0
# 9         0.005098       1.0       NaN       NaN       3.0       7.0      21.0
# 10        0.004613      30.0      40.0      65.0      50.0      41.0      19.0
# 11        0.037387     130.0     129.0     121.0      97.0     102.0     154.0
# 12             NaN       NaN       1.0       1.0       NaN       NaN       NaN
# 13        0.062878     408.0     376.0     352.0     265.0     259.0     259.0
# 14        0.045641     121.0     113.0     113.0     137.0     142.0     188.0
# 15        0.044427     183.0     191.0     190.0     163.0     185.0     183.0
# 16        0.007283      46.0      61.0      35.0      33.0      33.0      30.0
# 17        0.207085     995.0     969.0     979.0     912.0     927.0     853.0
# 18        0.025977      49.0      73.0      83.0     101.0     108.0     107.0
# 19             NaN       NaN       NaN       NaN       1.0       NaN       NaN
# 20        0.000728       1.0       4.0       6.0       NaN       NaN       3.0
# 21        0.000243       NaN       NaN       NaN       NaN       2.0       1.0
# 22             NaN       NaN       NaN       NaN       1.0       NaN       NaN
# 23             NaN       NaN       NaN       1.0       NaN       NaN       NaN
# 24        2.039048    8271.0    8514.0    8034.0    7860.0    7974.0    8399.0
# 25        0.004855      18.0      13.0      19.0      21.0      24.0      20.0
# 26        0.076231     247.0     251.0     258.0     274.0     283.0     314.0
# 27             NaN       NaN       NaN       NaN       NaN       1.0       NaN
# 28        0.042242     166.0     178.0     178.0     147.0     156.0     174.0
# 29        0.187420     448.0     504.0     509.0     543.0     653.0     772.0
# ..             ...       ...       ...       ...       ...       ...       ...
# 135       0.078901      61.0     240.0     243.0     271.0     290.0     325.0
# 136            NaN       1.0       NaN       NaN       NaN       1.0       NaN
# 137            NaN       NaN       NaN       2.0       NaN       NaN       NaN
# 138       0.008740      25.0      24.0      24.0      24.0      32.0      36.0
# 139       0.254426     683.0     713.0     819.0     842.0     968.0    1048.0
# 140       0.101965     422.0     445.0     390.0     370.0     388.0     420.0
# 141       0.000243      12.0      11.0      14.0      15.0      10.0       1.0
# 142       0.028647      65.0      59.0      50.0      70.0      94.0     118.0
# 143       0.071375     315.0     314.0     285.0     288.0     302.0     294.0
# 144       0.064578     275.0     248.0     229.0     243.0     265.0     266.0
# 145            NaN       NaN       NaN       NaN       2.0       NaN       NaN
# 146       0.000728      16.0      12.0       6.0       2.0       NaN       3.0
# 147       0.231848     903.0     811.0     975.0     865.0     950.0     955.0
# 148            NaN       NaN       1.0       2.0       NaN       NaN       NaN
# 149            NaN       NaN       1.0       NaN       NaN       NaN       NaN
# 150       0.051225     187.0     205.0     216.0     183.0     188.0     211.0
# 151       0.000728       NaN       NaN       2.0       NaN       2.0       3.0
# 152       0.033503      75.0     104.0      94.0      99.0      91.0     138.0
# 153       0.055838     136.0     163.0     183.0     181.0     193.0     230.0
# 154            NaN       2.0       NaN       NaN       NaN       NaN       NaN
# 155       0.003399      19.0      15.0      14.0       4.0      11.0      14.0
# 156       0.077687     165.0     157.0     188.0     202.0     247.0     320.0
# 157       0.491615    1629.0    1726.0    1852.0    1802.0    1912.0    2025.0
# 158      89.826369  348113.0  352742.0  347452.0  343132.0  358354.0  370002.0
# 159       0.010439      54.0      50.0      53.0      57.0      60.0      43.0
# 160       0.070404     377.0     373.0     389.0     350.0     335.0     290.0
# 161            NaN       1.0       1.0       2.0       NaN       NaN       NaN
# 162            NaN       NaN       1.0       NaN       NaN       NaN       NaN
# 163       0.000243       NaN       NaN       NaN       NaN       NaN       1.0
# 164            NaN       NaN       NaN       NaN       2.0       NaN       NaN
#
# [165 rows x 19 columns]
