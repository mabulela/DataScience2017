# %% [markdown]
#  # Instructions:
#  - For all cells marked with <font color="red">(CODE Needed)</font> below, replace `#CODE_HERE` with your solution

# %% [markdown]
# # 1. Load Spark Context (No CODE Needed)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit, desc, col, when, max
from functools import reduce

spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # 2. Load some printing functions (No CODE Needed)

# %%
#These are some printing helper functions we will use to make the output more clear
from pprint import pprint
def title(s):
    pprint("---- %s -----" %s)    
    
def see(s, v):
    pprint("---- %s -----" %s)
    pprint(v)

# %% [markdown]
# # 3. Load each file in an DF and add the year to the data (No CODE Needed)

# %%
def createOneYearDF(year):
    file = "../data/flight-data/csv/%s"%year+"*"
    see("year:"+str(year), file)
    fileDF =spark.read.csv(file, header=True)
    arrDF = fileDF\
                .withColumn("year", lit(str(year)))\
                .withColumn("count", fileDF["count"].cast("int"))
    see("DF count for year:"+str(year), arrDF.count())
    title("DF elements for year:"+str(year))
    for arr in (arrDF.take(5)):
        print(arr)
    return arrDF

separateDFs  = list(map(createOneYearDF, range(2010,2016)))
see("arrays of DF", separateDFs)
# Out:
# '---- year:2010 -----'
# '../data/flight-data/csv/2010*'
# '---- DF count for year:2010 -----'
# 255
# '---- DF elements for year:2010 -----'
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Romania', count=1, year='2010')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Ireland', count=264, year='2010')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='India', count=69, year='2010')
# Row(DEST_COUNTRY_NAME='Egypt', ORIGIN_COUNTRY_NAME='United States', count=24, year='2010')
# Row(DEST_COUNTRY_NAME='Equatorial Guinea', ORIGIN_COUNTRY_NAME='United States', count=1, year='2010')
# '---- year:2011 -----'
# '../data/flight-data/csv/2011*'
# '---- DF count for year:2011 -----'
# 255
# '---- DF elements for year:2011 -----'
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Saint Martin', count=2, year='2011')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Guinea', count=2, year='2011')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Croatia', count=1, year='2011')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Romania', count=3, year='2011')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Ireland', count=268, year='2011')
# '---- year:2012 -----'
# '../data/flight-data/csv/2012*'
# '---- DF count for year:2012 -----'
# 245
# '---- DF elements for year:2012 -----'
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Croatia', count=1, year='2012')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Ireland', count=252, year='2012')
# Row(DEST_COUNTRY_NAME='Egypt', ORIGIN_COUNTRY_NAME='United States', count=13, year='2012')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='India', count=62, year='2012')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Singapore', count=25, year='2012')
# '---- year:2013 -----'
# '../data/flight-data/csv/2013*'
# '---- DF count for year:2013 -----'
# 250
# '---- DF elements for year:2013 -----'
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Romania', count=12, year='2013')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Croatia', count=1, year='2013')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Ireland', count=266, year='2013')
# Row(DEST_COUNTRY_NAME='Egypt', ORIGIN_COUNTRY_NAME='United States', count=13, year='2013')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='India', count=60, year='2013')
# '---- year:2014 -----'
# '../data/flight-data/csv/2014*'
# '---- DF count for year:2014 -----'
# 241
# '---- DF elements for year:2014 -----'
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Saint Martin', count=1, year='2014')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Romania', count=12, year='2014')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Croatia', count=2, year='2014')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Ireland', count=291, year='2014')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='India', count=62, year='2014')
# '---- year:2015 -----'
# '../data/flight-data/csv/2015*'
# '---- DF count for year:2015 -----'
# 256
# '---- DF elements for year:2015 -----'
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Romania', count=15, year='2015')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Croatia', count=1, year='2015')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Ireland', count=344, year='2015')
# Row(DEST_COUNTRY_NAME='Egypt', ORIGIN_COUNTRY_NAME='United States', count=15, year='2015')
# Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='India', count=62, year='2015')
# '---- arrays of DF -----'
# [DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: int, year: string],
#  DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: int, year: string],
#  DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: int, year: string],
#  DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: int, year: string],
#  DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: int, year: string],
#  DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: int, year: string]]

# %% [markdown]
# # 4. Merge all DFs into one DF  (No CODE Needed)

# %%
allYearsDF = reduce(lambda df1, df2: df1.union(df2),separateDFs)

see("allYearsDF count", allYearsDF.count())
see("allYearsDF sample", allYearsDF.rdd.takeSample(False, 10, 17))
#allYearsDF.printSchema()
# Out:
# '---- allYearsDF count -----'
# 1502
# '---- allYearsDF sample -----'
# [Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Jamaica', count=714, year='2014'),
#  Row(DEST_COUNTRY_NAME='Senegal', ORIGIN_COUNTRY_NAME='United States', count=29, year='2011'),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Samoa', count=28, year='2010'),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Singapore', count=24, year='2011'),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Saint Barthelemy', count=58, year='2013'),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Afghanistan', count=5, year='2012'),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Russia', count=151, year='2014'),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Thailand', count=4, year='2015'),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Sweden', count=68, year='2011'),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Grenada', count=46, year='2012')]
# root
#  |-- DEST_COUNTRY_NAME: string (nullable = true)
#  |-- ORIGIN_COUNTRY_NAME: string (nullable = true)
#  |-- count: integer (nullable = true)
#  |-- year: string (nullable = false)

# %% [markdown]
# # 5. Compute a DF containing all flights which departed from US  <font color="red">(CODE Needed)</font>
# - Hint: make 1 `filter` transformation

# %%
fromUSRdd = allYearsDF.where("ORIGIN_COUNTRY_NAME = 'United States'")
see("fromUSRdd count",fromUSRdd.count())

title("fromUSRdd show(10)")
fromUSRdd.show(10)
# Out:
# '---- fromUSRdd count -----'
# 772
# '---- fromUSRdd show(10) -----'
# +--------------------+-------------------+-----+----+
# |   DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|year|
# +--------------------+-------------------+-----+----+
# |               Egypt|      United States|   24|2010|
# |   Equatorial Guinea|      United States|    1|2010|
# |          Costa Rica|      United States|  477|2010|
# |             Senegal|      United States|   29|2010|
# |              Guyana|      United States|   17|2010|
# |               Malta|      United States|    1|2010|
# |             Bolivia|      United States|   46|2010|
# |            Anguilla|      United States|   21|2010|
# |Turks and Caicos ...|      United States|  136|2010|
# |Saint Vincent and...|      United States|    1|2010|
# +--------------------+-------------------+-----+----+
# only showing top 10 rows

# %% [markdown]
# ### Expectated output for step 5.
#
# <pre>
# '---- fromUSRdd count -----'
# 772
# '---- fromUSRdd show(10) -----'
# +--------------------+-------------------+-----+----+
# |   DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|year|
# +--------------------+-------------------+-----+----+
# |               Egypt|      United States|   24|2010|
# |   Equatorial Guinea|      United States|    1|2010|
# |          Costa Rica|      United States|  477|2010|
# |             Senegal|      United States|   29|2010|
# |              Guyana|      United States|   17|2010|
# |               Malta|      United States|    1|2010|
# |             Bolivia|      United States|   46|2010|
# |            Anguilla|      United States|   21|2010|
# |Turks and Caicos ...|      United States|  136|2010|
# |Saint Vincent and...|      United States|    1|2010|
# +--------------------+-------------------+-----+----+
# only showing top 10 rows
# </pre>

# %% [markdown]
# # 6. Sum all the flights for the same destination and the same year <font color="red">(CODE Needed)</font>
# - Hint: make 1 `groupBy` and 1 `sum` transformations

# %%
groupedRdd = fromUSRdd.groupBy("DEST_COUNTRY_NAME","year").sum("count").withColumnRenamed("sum(count)","flight_count")

see("groupedRdd count",groupedRdd.count())

title("groupedRdd show(10)")
groupedRdd.show(10)
# Out:
# '---- groupedRdd count -----'
# 772
# '---- groupedRdd show(10) -----'
# +-----------------+----+------------+
# |DEST_COUNTRY_NAME|year|flight_count|
# +-----------------+----+------------+
# |      Saint Lucia|2011|         102|
# |          Hungary|2014|           2|
# |       Guadeloupe|2014|          43|
# |          Nigeria|2014|          49|
# |             Fiji|2015|          24|
# |           Kuwait|2010|          26|
# |   Cayman Islands|2011|         251|
# |         Paraguay|2011|          85|
# |          Austria|2011|          34|
# |        Gibraltar|2014|           1|
# +-----------------+----+------------+
# only showing top 10 rows

# %% [markdown]
# ### Exepected output for step  6
# <pre>
# '---- groupedRdd count -----'
# 772
# '---- groupedRdd take(10) -----'
# +-----------------+----+------------+
# |DEST_COUNTRY_NAME|year|flight_count|
# +-----------------+----+------------+
# |      Saint Lucia|2011|         102|
# |          Hungary|2014|           2|
# |       Guadeloupe|2014|          43|
# |          Nigeria|2014|          49|
# |             Fiji|2015|          24|
# |           Kuwait|2010|          26|
# |   Cayman Islands|2011|         251|
# |         Paraguay|2011|          85|
# |          Austria|2011|          34|
# |        Gibraltar|2014|           1|
# +-----------------+----+------------+
# only showing top 10 rows
#  </pre>

# %% [markdown]
# # 7. Sort the summed data by the highest sum <font color="red">(CODE Needed)</font>
# - Hint: make 1 `orderBy` transformation

# %%
sortedByCountRdd = groupedRdd.orderBy(desc("flight_count"))

see("sortedByCountRdd count",sortedByCountRdd.count())

title("sortedByCountRdd show(10)")
sortedByCountRdd.show(10)
# Out:
# '---- sortedByCountRdd count -----'
# 772
# '---- sortedByCountRdd show(10) -----'
# +-----------------+----+------------+
# |DEST_COUNTRY_NAME|year|flight_count|
# +-----------------+----+------------+
# |    United States|2015|      370002|
# |    United States|2014|      358354|
# |    United States|2011|      352742|
# |    United States|2010|      348113|
# |    United States|2012|      347452|
# |    United States|2013|      343132|
# |           Canada|2011|        8514|
# |           Canada|2015|        8399|
# |           Canada|2010|        8271|
# |           Canada|2012|        8034|
# +-----------------+----+------------+
# only showing top 10 rows

# %% [markdown]
# ### Exepected output for step  7
# <pre>
# '---- sortedByCountRdd count -----'
# 772
# '---- sortedByCountRdd show(10) -----'
# +-----------------+----+------------+
# |DEST_COUNTRY_NAME|year|flight_count|
# +-----------------+----+------------+
# |    United States|2015|      370002|
# |    United States|2014|      358354|
# |    United States|2011|      352742|
# |    United States|2010|      348113|
# |    United States|2012|      347452|
# |    United States|2013|      343132|
# |           Canada|2011|        8514|
# |           Canada|2015|        8399|
# |           Canada|2010|        8271|
# |           Canada|2012|        8034|
# +-----------------+----+------------+
# only showing top 10 rows
#  </pre>

# %% [markdown]
# # 8. Compute the Sum of all Trips <font color="red">(CODE Needed)</font>
# - Hint: make 1 `agg` or 1 `groupBy` and 1 `sum` transformations

# %%
sumAllTrips = sortedByCountRdd.agg({"flight_count":"sum"}).withColumnRenamed("sum(flight_count)","total_count")

title("sumAllTrips")
sumAllTrips.show()
# Out:
# '---- sumAllTrips -----'
# +-----------+
# |total_count|
# +-----------+
# |    2352430|
# +-----------+

# %% [markdown]
# ### Exepected output for step  8
# <pre>
# '---- sumAllTrips -----'
# +-----------+
# |total_count|
# +-----------+
# |    2352430|
# +-----------+
#  </pre>

# %% [markdown]
# # 9. Compute the Sum of Each Year's Trip <font color="red">(CODE Needed)</font>
# - Hint: make 1 `groupBy` , 1 `sum` transformations and 1 `collectAsMap`

# %%
TPY = sortedByCountRdd.groupBy("year").sum("flight_count").rdd.collectAsMap()

see("TPY", TPY)
# Out:
# '---- TPY -----'
# {'2010': 385450,
#  '2011': 390663,
#  '2012': 385290,
#  '2013': 381039,
#  '2014': 398022,
#  '2015': 411966}

# %% [markdown]
# ### Exepected output for step  9
# <pre>
# '---- TPY -----'
# {'2010': 385450,
#  '2011': 390663,
#  '2012': 385290,
#  '2013': 381039,
#  '2014': 398022,
#  '2015': 411966}
#  </pre>

# %% [markdown]
# # 10. Use the above sums to compute percent Per Year, percent from Total for each country, year pair <font color="red">(CODE Needed)</font>
# - Hint: make 1 `groupBy`, 1 `pivote` transformations

# %%
import pandas as pd
stats = sortedByCountRdd.groupBy("DEST_COUNTRY_NAME")\
    .pivot("year")\
    .agg({"flight_count":"sum"})\
    .fillna(0)\
    .withColumnRenamed("DEST_COUNTRY_NAME","Country")\
    .sort("DEST_COUNTRY_NAME")
#    .withColumn("test", lit(0))

#lll = stats.select("Country").rdd.map(lambda v: v[0]).collect()

see("stats count",stats.count())

title("stats show(10)")
stats.show(10)

#for column in stats:
    #print (stats.select(column).rdd.map(lambda v: v[0]).take(2))
#stats.printSchema(
#stats.select("2010","2011").rdd.map(lambda v: (v[0],v[1])).take(2)
# Out:
# '---- stats count -----'
# 167
# '---- stats show(10) -----'
# +-------------------+----+----+----+----+----+----+
# |            Country|2010|2011|2012|2013|2014|2015|
# +-------------------+----+----+----+----+----+----+
# |        Afghanistan|  11|   8|   5|   0|   0|   0|
# |            Algeria|   0|   0|   0|   2|   9|   4|
# |             Angola|  14|  13|  12|  12|  13|  15|
# |           Anguilla|  21|  21|  19|  22|  34|  41|
# |Antigua and Barbuda| 123| 146| 145| 123| 115| 126|
# |          Argentina| 184| 183| 208| 176| 195| 180|
# |              Aruba| 359| 347| 349| 352| 351| 346|
# |          Australia| 290| 280| 277| 295| 293| 329|
# |            Austria|  36|  34|  34|  35|  47|  62|
# |         Azerbaijan|   1|   0|   0|   3|   7|  21|
# +-------------------+----+----+----+----+----+----+
# only showing top 10 rows

# %% [markdown]
# ### Exepected output for step  10
# <pre>
# '---- stats count -----'
# 167
# '---- stats show(10) -----'
# +-------------------+----+----+----+----+----+----+
# |            Country|2010|2011|2012|2013|2014|2015|
# +-------------------+----+----+----+----+----+----+
# |        Afghanistan|  11|   8|   5|   0|   0|   0|
# |            Algeria|   0|   0|   0|   2|   9|   4|
# |             Angola|  14|  13|  12|  12|  13|  15|
# |           Anguilla|  21|  21|  19|  22|  34|  41|
# |Antigua and Barbuda| 123| 146| 145| 123| 115| 126|
# |          Argentina| 184| 183| 208| 176| 195| 180|
# |              Aruba| 359| 347| 349| 352| 351| 346|
# |          Australia| 290| 280| 277| 295| 293| 329|
# |            Austria|  36|  34|  34|  35|  47|  62|
# |         Azerbaijan|   1|   0|   0|   3|   7|  21|
# +-------------------+----+----+----+----+----+----+
# only showing top 10 rows
#  </pre>

# %% [markdown]
# # 11. Transform the above table into the format below <font color="red">(CODE Needed)</font>
# - Hint: use `withColumn`
# - use the function `percent`
# - use `TPY` as a lookup table

# %%
def percent(number, total):
    return 100.0* number/float(total)

totalFlightCount = sumAllTrips.first()[0]

years = list(map(lambda year: year[0], 
                 sortedByCountRdd.select("year").distinct().orderBy("year").collect()))

Table = stats.withColumn("PcntTotal-2010", percent(stats["2010"],2352430))\
    .withColumn("PcntYear-2010", percent(stats["2010"],TPY["2010"]))\
    .withColumn("PcntTotal-2011", percent(stats["2011"],2352430))\
    .withColumn("PcntYear-2011", percent(stats["2011"],TPY["2011"]))\
    .withColumn("PcntTotal-2012", percent(stats["2012"],2352430))\
    .withColumn("PcntYear-2012", percent(stats["2012"],TPY["2012"]))\
    .withColumn("PcntTotal-2013", percent(stats["2013"],2352430))\
    .withColumn("PcntYear-2013", percent(stats["2013"],TPY["2013"]))\
    .withColumn("PcntTotal-2014", percent(stats["2014"],2352430))\
    .withColumn("PcntYear-2014", percent(stats["2014"],TPY["2014"]))\
    .withColumn("PcntTotal-2015", percent(stats["2015"],2352430))\
    .withColumn("PcntYear-2015", percent(stats["2015"],TPY["2015"]))

see("Table count",Table.count())

title("Table show(10)")
Table.show(10)
# Out:
# '---- Table count -----'
# 167
# '---- Table show(10) -----'
# +-------------------+----+----+----+----+----+----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |            Country|2010|2011|2012|2013|2014|2015|      PcntTotal-2010|       PcntYear-2010|      PcntTotal-2011|       PcntYear-2011|      PcntTotal-2012|       PcntYear-2012|      PcntTotal-2013|       PcntYear-2013|      PcntTotal-2014|       PcntYear-2014|      PcntTotal-2015|       PcntYear-2015|
# +-------------------+----+----+----+----+----+----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |
# 8                              Austria      36      34      34      35
# 9                           Azerbaijan       1       0       0       3
# 10                             Bahrain      30      40      65      50
# 11                            Barbados     130     129     121      97
# 12                             Belarus       0       1       1       0
# 13                             Belgium     408     376     352     265
# 14                              Belize     121     113     113     137
# 15                             Bermuda     183     191     190     163
# 16                             Bolivia      46      61      35      33
# 17   Bonaire, Sint Eustatius, and Saba      16      50      46      53
# 18                              Brazil     995     969     979     912
# 19              British Virgin Islands      49      73      83     101
# 20                              Brunei       0       0       0       1
# 21                            Bulgaria       1       4       6       0
# 22                        Burkina Faso       0       0       0       0
# 23                             Burundi       0       0       0       1
# 24                            Cameroon       0       0       1       0
# 25                              Canada    8271    8514    8034    7860
# 26                          Cape Verde      18      13      19      21
# 27                      Cayman Islands     247     251     258     274
# 28                                Chad       0       0       0       0
# 29                               Chile     166     178     178     147
# ..                                 ...     ...     ...     ...     ...
# 137                       Sint Maarten      61     240     243     271
# 138                           Slovakia       1       0       0       0
# 139                    Solomon Islands       0       0       2       0
# 140                       South Africa      25      24      24      24
# 141                        South Korea     683     713     819     842
# 142                              Spain     422     445     390     370
# 143                           Suriname      12      11      14      15
# 144                             Sweden      65      59      50      70
# 145                        Switzerland     315     314     285     288
# 146                             Taiwan     275     248     229     243
# 147                           Tanzania       0       0       0       2
# 148                           Thailand      16      12       6       2
# 149                        The Bahamas     903     811     975     865
# 150                         The Gambia       0       1       2       0
# 151                               Togo       0       1       0       0
# 152                Trinidad and Tobago     187     205     216     183
# 153                            Tunisia       0       0       2       0
# 154                             Turkey      75     104      94      99
# 155           Turks and Caicos Islands     136     163     183     181
# 156                             Uganda       2       0       0       0
# 157                            Ukraine      19      15      14       4
# 158               United Arab Emirates     165     157     188     202
# 159                     United Kingdom    1629    1726    1852    1802
# 160                      United States  348113  352742  347452  343132
# 161                            Uruguay      54      50      53      57
# 162                          Venezuela     377     373     389     350
# 163                            Vietnam       1       1       2       0
# 164                              Yemen       0       1       0       0
# 165                             Zambia       0       0       0       0
# 166                           Zimbabwe       0       0       0       2
#
#        2014    2015  PcntTotal-2010  PcntYear-2010  PcntTotal-2011  \
# 0         0       0        0.000468       0.002854        0.000340
# 1         9       4        0.000000       0.000000        0.000000
# 2        13      15        0.000595       0.003632        0.000553
# 3        34      41        0.000893       0.005448        0.000893
# 4       115     126        0.005229       0.031911        0.006206
# 5       195     180        0.007822       0.047736        0.007779
# 6       351     346        0.015261       0.093138        0.014751
# 7       293     329        0.012328       0.075237        0.011903
# 8        47      62        0.001530       0.009340        0.001445
# 9         7      21        0.000043       0.000259        0.000000
# 10       41      19        0.001275       0.007783        0.001700
# 11      102     154        0.005526       0.033727        0.005484
# 12        0       0        0.000000       0.000000        0.000043
# 13      259     259        0.017344       0.105850        0.015983
# 14      142     188        0.005144       0.031392        0.004804
# 15      185     183        0.007779       0.047477        0.008119
# 16       33      30        0.001955       0.011934        0.002593
# 17       62      58        0.000680       0.004151        0.002125
# 18      927     853        0.042297       0.258140        0.041191
# 22        0.000000        0.000085       0.000502        0.000043
# 23        0.000262        0.000000       0.000000        0.000000
# 24        0.000000        0.000000       0.000000        0.000000
# 25        2.062781        0.338969       2.003407        0.357035
# 26        0.005511        0.001020       0.006030        0.000850
# 27        0.071909        0.012030       0.071102        0.013348
# 28        0.000000        0.000043       0.000251        0.000000
# 29        0.038579        0.006631       0.039194        0.007397
# ..             ...             ...            ...             ...
# 137       0.071121        0.012328       0.072860        0.013816
# 138       0.000000        0.000043       0.000251        0.000000
# 139       0.000000        0.000000       0.000000        0.000000
# 140       0.006299        0.001360       0.008040        0.001530
# 141       0.220975        0.041149       0.243203        0.044550
# 142       0.097103        0.016494       0.097482        0.017854
# 143       0.003937        0.000425       0.002512        0.000043
# 144       0.018371        0.003996       0.023617        0.005016
# 145       0.075583        0.012838       0.075875        0.012498
# 146       0.063773        0.011265       0.066579        0.011307
# 147       0.000525        0.000000       0.000000        0.000000
# 148       0.000525        0.000000       0.000000        0.000128
# 149       0.227011        0.040384       0.238680        0.040596
# 150       0.000000        0.000000       0.000000        0.000000
# 151       0.000000        0.000000       0.000000        0.000000
# 152       0.048027        0.007992       0.047234        0.008969
# 153       0.000000        0.000085       0.000502        0.000128
# 154       0.025982        0.003868       0.022863        0.005866
# 155       0.047502        0.008204       0.048490        0.009777
# 156       0.000000        0.000000       0.000000        0.000000
# 157       0.001050        0.000468       0.002764        0.000595
# 158       0.053013        0.010500       0.062057        0.013603
# 159       0.472917        0.081278       0.480375        0.086081
# 160      90.051675       15.233354      90.033717       15.728502
# 161       0.014959        0.002551       0.015075        0.001828
# 162       0.091854        0.014241       0.084166        0.012328
# 163       0.000000        0.000000       0.000000        0.000000
# 164       0.000000        0.000000       0.000000        0.000000
# 165       0.000000        0.000000       0.000000        0.000043
# 166       0.000525        0.000000       0.000000        0.000000
#
#      PcntYear-2015
# 0         0.000000
# 1         0.000971
# 2         0.003641
# 3         0.009952
# 4         0.030585
# 5         0.043693
# 6         0.083988
# 7         0.079861
# 8         0.015050
# 9         0.005098
# 10        0.004612
# 11        0.037382
# 12        0.000000
# 13        0.062869
# 14        0.045635
# 15        0.044421
# 16        0.007282
# 17        0.014079
# 18        0.207056
# 19        0.025973
# 20        0.000000
# 21        0.000728
# 22        0.000243
# 23        0.000000
# 24        0.000000
# 25        2.038760
# 26        0.004855
# 27        0.076220
# 28        0.000000
# 29        0.042236
# ..             ...
# 137       0.078890
# 138       0.000000
# 139       0.000000
# 140       0.008739
# 141       0.254390
# 142       0.101950
# 143       0.000243
# 144       0.028643
# 145       0.071365
# 146       0.064568
# 147       0.000000
# 148       0.000728
# 149       0.231815
# 150       0.000000
# 151       0.000000
# 152       0.051218
# 153       0.000728
# 154       0.033498
# 155       0.055830
# 156       0.000000
# 157       0.003398
# 158       0.077676
# 159       0.491545
# 160      89.813722
# 161       0.010438
# 162       0.070394
# 163       0.000000
# 164       0.000000
# 165       0.000243
# 166       0.000000
#
# [167 rows x 19 columns]
